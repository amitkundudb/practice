# %%
df = spark.read.format("csv").load("/FileStore/onlinefoods.csv",header = 'True')
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df.write.option("header", True).mode("overwrite").partitionBy("Occupation").csv("/dbfs/FileStore/temp/")

# %%
# %sql
-- Create table with partitions
CREATE TABLE IF NOT EXISTS emp2 (
    id INT,
    name STRING,
    Age INT
) 
USING PARQUET
PARTITIONED BY (city STRING);

-- Insert data into the table
INSERT OVERWRITE TABLE emp PARTITION (city)
VALUES 
    (1, 'John', 25, 'Mumbai'),
    (2, 'Smith', 30, 'Delhi'),
    (3, 'Lisa', 28, 'Bangalore'),
    (4, 'Emma', 35, 'Mumbai'),
    (5, 'James', 40, 'Kolkata');

SHOW PARTITIONS emp2;
SELECT Age from emp2;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>name</th><th>Age</th></tr></thead><tbody></tbody></table></div>

# %%
_sqldf.write.format("csv").option("replacewhere","Age > 20").mode("overwrite").save("/FileStore/onlinefoods.csv")
spark.read.format("csv").load("/FileStore/onlinefoods.csv").show()
# Out:
# ++
# ||
# ++
# ++
